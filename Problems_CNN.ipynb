# %% [markdown]
# ## Get the Data

# %% [markdown]
# Note : **`Non-graded challenge projects are in the Google Colab environment.`**

# %%
import zipfile

# Download zip file of pizza_steak images
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip 

# Unzip the downloaded file
zip_ref = zipfile.ZipFile("pizza_steak.zip", "r")
zip_ref.extractall()
zip_ref.close()
# Out:
# --2023-06-07 06:59:32--  https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.137.128, 142.250.141.128, 142.250.101.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.137.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109540975 (104M) [application/zip]
# Saving to: ‘pizza_steak.zip’
#
# pizza_steak.zip     100%[===================>] 104.47M   148MB/s    in 0.7s
#
# 2023-06-07 06:59:33 (148 MB/s) - ‘pizza_steak.zip’ saved [109540975/109540975]

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("pizza_steak"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in 'pizza_steak'.
# There are 2 directories and 0 images in 'pizza_steak/test'.
# There are 0 directories and 250 images in 'pizza_steak/test/pizza'.
# There are 0 directories and 250 images in 'pizza_steak/test/steak'.
# There are 2 directories and 0 images in 'pizza_steak/train'.
# There are 0 directories and 750 images in 'pizza_steak/train/pizza'.
# There are 0 directories and 750 images in 'pizza_steak/train/steak'.

# %% [markdown]
# ## Please visualize one of the datasets you have down below using `matplotlib.image` and show the image shape

# %%
# Out:
# Image shape: (512, 512, 3)

# %% [markdown]
# please write your analysis down below :
#
# 1.   What do you know about the shape of the image?
# 2.   What value does the shape of the image represent?

# %% [markdown]
# ## Please preprocess data (get all of the pixel values between 1 and 0, also called scaling/normalization) using `ImageDataGenerator` from tensorflow

# %%
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %% [markdown]
# ## Please show one batch of the train data after scaling using `matplotlib.pyplot`

# %% [markdown]
# please write your analysis down below :
#
# 1.   Why do we have to scale the data before it enters the model?

# %% [markdown]
# ## Please preprocess data (Data augmentation) using `ImageDataGenerator` from tensorflow

# %%
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %% [markdown]
# ## Please show one batch of the train data after augmentation using `matplotlib.pyplot`

# %% [markdown]
# please write your analysis down below :
#
# 1.   What are the advantages of using data augmentation?
# 2.   What parameters do you use in data augmentation, and could you explain them?
